# %%
#cloning into the repository that is mentioned in the report of phase1
# !git clone https://github.com/google/tirg.git
# Out:
# Cloning into 'tirg'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 54 (delta 13), reused 11 (delta 11), pack-reused 36
# Receiving objects: 100% (54/54), 1022.52 KiB | 23.78 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# making separate directory to load datasets.
# !mkdir /content/datasets

# %%
#Mounting on to google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# copying the css dataset to required dataset directory
# !cp "CSS.zip" "/content/datasets/CSS.zip"

# %%
# %cd /content/datasets
# Out:
# /content/datasets

# %%
#Unzipping the contents of dataset
# !unzip CSS.zip -d /content/datasets/CSS
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/datasets/CSS/scenes/css_test_011392.json
#   inflating: /content/datasets/CSS/scenes/css_train_010221.json
#   inflating: /content/datasets/CSS/scenes/css_test_009078.json
#   inflating: /content/datasets/CSS/scenes/css_test_002641.json
#   inflating: /content/datasets/CSS/scenes/css_train_009071.json
#   inflating: /content/datasets/CSS/scenes/css_train_010351.json
#   inflating: /content/datasets/CSS/scenes/css_train_011921.json
#   inflating: /content/datasets/CSS/scenes/css_test_006402.json
#   inflating: /content/datasets/CSS/scenes/css_train_001027.json
#   inflating: /content/datasets/CSS/scenes/css_train_017472.json
#   inflating: /content/datasets/CSS/scenes/css_test_008258.json
#   inflating: /content/datasets/CSS/scenes/css_train_001425.json
#   inflating: /content/datasets/CSS/scenes/css_train_008229.json
#   inflating: /content/datasets/CSS/scenes/css_test_008433.json
# ...

# %%
# !ls /content/datasets
# Out:
# CSS  CSS.zip

# %%
# directing back to main directory i.e., tirg
# %cd /content/tirg
# Out:
# /content/tirg

# %%
# installing tensor box
# !pip install tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.1 MB/s eta 0:00:00
# ...

# %%
 # Trains 'tirg' model on CSS3D dataset using soft triplet loss for 160,000 iterations.
# Dataset located at '/content/datasets/CSS', identified by comment 'css3d_tirg'

# !python main.py --dataset=css3d --dataset_path=/content/datasets/CSS --num_iters=160000 --model=tirg --loss=soft_triplet --comment=css3d_tirg
# Out:
# Arguments:
#      f :
#      comment : css3d_tirg
#      dataset : css3d
#      dataset_path : /content/datasets/CSS
#      model : tirg
#      embed_dim : 512
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 9999999
#      batch_size : 32
#      weight_decay : 1e-06
#      num_iters : 160000
#      loss : soft_triplet
#      loader_num_workers : 4
# Log files saved to runs/Nov30_06-10-54_ca0e0c7a72cccss3d_tirg
# Reading dataset  css3d
# trainset size: 19012
# testset size: 19057
# Creating model and optimizer for tirg
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# Same as above cell but with lesser no. of iterations.
# !python main.py --dataset=css3d --dataset_path=/content/datasets/CSS --num_iters=5000 --model=tirg --loss=soft_triplet --comment=css3d_tirg
# Out:
# Arguments:
#      f :
#      comment : css3d_tirg
#      dataset : css3d
#      dataset_path : /content/datasets/CSS
#      model : tirg
#      embed_dim : 512
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 9999999
#      batch_size : 32
#      weight_decay : 1e-06
#      num_iters : 5000
#      loss : soft_triplet
#      loader_num_workers : 4
# Log files saved to runs/Dec02_12-13-49_03833be48f18css3d_tirg
# Reading dataset  css3d
# trainset size: 19012
# testset size: 19057
# Creating model and optimizer for tirg
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# Trains 'tirg_lastconv' model on CSS3D dataset using soft triplet loss for 16,000 iterations.
# Dataset located at '/content/datasets/CSS', identified by comment 'css3d_tirgconv'.
# !python main.py --dataset=css3d --dataset_path=/content/datasets/CSS --num_iters=16000 --model=tirg_lastconv --loss=soft_triplet --comment=css3d_tirgconv
# Out:
# Arguments:
#      f :
#      comment : css3d_tirgconv
#      dataset : css3d
#      dataset_path : /content/datasets/CSS
#      model : tirg_lastconv
#      embed_dim : 512
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 9999999
#      batch_size : 32
#      weight_decay : 1e-06
#      num_iters : 16000
#      loss : soft_triplet
#      loader_num_workers : 4
# Log files saved to runs/Dec02_10-56-25_03833be48f18css3d_tirgconv
# Reading dataset  css3d
# trainset size: 19012
# testset size: 19057
# Creating model and optimizer for tirg_lastconv
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# Tests 'concat' model on CSS3D dataset using soft triplet loss for 10 iterations with a batch size of 64.
# Dataset located at '/content/datasets/CSS', identified by comment 'css3d_concat_test'.
# !python main.py --dataset=css3d --dataset_path=/content/datasets/CSS --num_iters=10 \
  --model=concat --loss=soft_triplet --comment=css3d_concat_test --batch_size=64
# Out:
# Arguments:
#      f :
#      comment : css3d_concat_test
#      dataset : css3d
#      dataset_path : /content/datasets/CSS
#      model : concat
#      embed_dim : 512
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 9999999
#      batch_size : 64
#      weight_decay : 1e-06
#      num_iters : 10
#      loss : soft_triplet
#      loader_num_workers : 4
# Log files saved to runs/Dec02_10-45-24_03833be48f18css3d_concat_test
# Reading dataset  css3d
# trainset size: 19012
# testset size: 19057
# Creating model and optimizer for concat
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# Same as above cell but increased no. of iterations
# !python main.py --dataset=css3d --dataset_path=/content/datasets/CSS --num_iters=16000\
  --model=concat --loss=soft_triplet --comment=css3d_concat
# Out:
# Arguments:
#      f :
#      comment : css3d_concat
#      dataset : css3d
#      dataset_path : /content/datasets/CSS
#      model : concat
#      embed_dim : 512
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 9999999
#      batch_size : 32
#      weight_decay : 1e-06
#      num_iters : 16000
#      loss : soft_triplet
#      loader_num_workers : 4
# Log files saved to runs/Dec02_12-55-55_03833be48f18css3d_concat
# Reading dataset  css3d
# trainset size: 19012
# testset size: 19057
# Creating model and optimizer for concat
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
